# %% [markdown]
# ## **Business & Data Understaning**

# %%
import pandas as pd
df=pd.read_csv("/content/airline-passengers.csv")
df.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
df.tail()
# Out:
#        Month  Passengers
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# This dataset include history of 12 years from **1949-01** to **1960-12**

# %%
import matplotlib.pyplot as plt
plt.xlabel('Months')
plt.ylabel('Number of Passengers')
plt.title('Distribution of the number of passengers over 12 years')
plt.plot(df['Passengers'])
plt.show()

# %% [markdown]
# ## **Data Preparation**

# %%
def load_data(data, seq_len):
  X = []
  y = []
  for i in range(seq_len, len(data)):
    X.append(data.iloc[i-seq_len : i, 1])
    y.append(data.iloc[i,1])
  return X,y

# %%
X,y=load_data(df,20)

# %%
len(y)
# Out:
# 124

# %%
X_train=X[:100]
y_train=y[:100]
X_test=X[100:]
y_test=y[100:]

# %%
import numpy as np
X_train=np.array(X_train)
y_train=np.array(y_train)
X_test=np.array(X_test)
y_test=np.array(y_test)

# %%
X_train
# Out:
# array([[112, 118, 132, ..., 149, 170, 170],
#        [118, 132, 129, ..., 170, 170, 158],
#        [132, 129, 121, ..., 170, 158, 133],
#        ...,
#        [301, 356, 348, ..., 491, 505, 404],
#        [356, 348, 355, ..., 505, 404, 359],
#        [348, 355, 422, ..., 404, 359, 310]])

# %%
print('x_train.shape = ',X_train.shape)
print('y_train.shape = ', y_train.shape)
print('x_test.shape = ', X_test.shape)
print('y_test.shape = ', y_test.shape)
# Out:
# x_train.shape =  (100, 20)
# y_train.shape =  (100,)
# x_test.shape =  (24, 20)
# y_test.shape =  (24,)

# %%
X_train = np.reshape(X_train, (100, 20, 1))
X_test = np.reshape(X_test, (24, 20, 1))

# %%
print('x_train.shape = ',X_train.shape)
print('y_train.shape = ', y_train.shape)
print('x_test.shape = ', X_test.shape)
print('y_test.shape = ', y_test.shape)
# Out:
# x_train.shape =  (100, 20)
# y_train.shape =  (100,)
# x_test.shape =  (24, 20)
# y_test.shape =  (24,)

# %% [markdown]
# ## **Neural Network from Keras**

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(40, input_shape=(20,),activation='relu'))
model.add(Dense(40,activation='relu'))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=500, batch_size=2, verbose=2)
# Out:
# Epoch 1/500
# 50/50 - 1s - loss: 8931.7559 - 909ms/epoch - 18ms/step
# Epoch 2/500
# 50/50 - 0s - loss: 900.2935 - 73ms/epoch - 1ms/step
# Epoch 3/500
# 50/50 - 0s - loss: 687.5327 - 68ms/epoch - 1ms/step
# Epoch 4/500
# 50/50 - 0s - loss: 631.0620 - 73ms/epoch - 1ms/step
# Epoch 5/500
# 50/50 - 0s - loss: 528.4342 - 78ms/epoch - 2ms/step
# Epoch 6/500
# 50/50 - 0s - loss: 477.3054 - 72ms/epoch - 1ms/step
# Epoch 7/500
# 50/50 - 0s - loss: 433.2821 - 72ms/epoch - 1ms/step
# Epoch 8/500
# 50/50 - 0s - loss: 444.4915 - 78ms/epoch - 2ms/step
# Epoch 9/500
# 50/50 - 0s - loss: 506.9724 - 74ms/epoch - 1ms/step
# Epoch 10/500
# 50/50 - 0s - loss: 420.0892 - 73ms/epoch - 1ms/step
# Epoch 11/500
# 50/50 - 0s - loss: 385.1682 - 75ms/epoch - 1ms/step
# Epoch 12/500
# 50/50 - 0s - loss: 399.7555 - 72ms/epoch - 1ms/step
# Epoch 13/500
# 50/50 - 0s - loss: 455.8631 - 70ms/epoch - 1ms/step
# Epoch 14/500
# 50/50 - 0s - loss: 400.5811 - 72ms/epoch - 1ms/step
# Epoch 15/500
# 50/50 - 0s - loss: 479.7157 - 80ms/epoch - 2ms/step
# Epoch 16/500
# 50/50 - 0s - loss: 383.7930 - 79ms/epoch - 2ms/step
# Epoch 17/500
# 50/50 - 0s - loss: 356.4715 - 71ms/epoch - 1ms/step
# Epoch 18/500
# 50/50 - 0s - loss: 289.9839 - 82ms/epoch - 2ms/step
# Epoch 19/500
# 50/50 - 0s - loss: 300.0370 - 73ms/epoch - 1ms/step
# Epoch 20/500
# 50/50 - 0s - loss: 242.1254 - 70ms/epoch - 1ms/step
# Epoch 21/500
# 50/50 - 0s - loss: 344.6162 - 74ms/epoch - 1ms/step
# Epoch 22/500
# 50/50 - 0s - loss: 386.5470 - 75ms/epoch - 2ms/step
# Epoch 23/500
# 50/50 - 0s - loss: 261.9386 - 70ms/epoch - 1ms/step
# Epoch 24/500
# 50/50 - 0s - loss: 257.8213 - 83ms/epoch - 2ms/step
# Epoch 25/500
# 50/50 - 0s - loss: 260.6521 - 73ms/epoch - 1ms/step
# Epoch 26/500
# 50/50 - 0s - loss: 315.2196 - 72ms/epoch - 1ms/step
# Epoch 27/500
# 50/50 - 0s - loss: 278.3662 - 71ms/epoch - 1ms/step
# Epoch 28/500
# 50/50 - 0s - loss: 214.2037 - 71ms/epoch - 1ms/step
# Epoch 29/500
# 50/50 - 0s - loss: 210.3652 - 72ms/epoch - 1ms/step
# Epoch 30/500
# 50/50 - 0s - loss: 210.2145 - 87ms/epoch - 2ms/step
# Epoch 31/500
# 50/50 - 0s - loss: 245.3564 - 108ms/epoch - 2ms/step
# Epoch 32/500
# 50/50 - 0s - loss: 321.5005 - 104ms/epoch - 2ms/step
# Epoch 33/500
# 50/50 - 0s - loss: 207.3779 - 96ms/epoch - 2ms/step
# Epoch 34/500
# 50/50 - 0s - loss: 196.9509 - 101ms/epoch - 2ms/step
# Epoch 35/500
# 50/50 - 0s - loss: 263.9721 - 109ms/epoch - 2ms/step
# Epoch 36/500
# 50/50 - 0s - loss: 208.0806 - 108ms/epoch - 2ms/step
# Epoch 37/500
# 50/50 - 0s - loss: 242.9787 - 115ms/epoch - 2ms/step
# Epoch 38/500
# 50/50 - 0s - loss: 247.0735 - 110ms/epoch - 2ms/step
# Epoch 39/500
# 50/50 - 0s - loss: 224.7444 - 115ms/epoch - 2ms/step
# Epoch 40/500
# 50/50 - 0s - loss: 262.4686 - 104ms/epoch - 2ms/step
# Epoch 41/500
# 50/50 - 0s - loss: 203.9003 - 102ms/epoch - 2ms/step
# Epoch 42/500
# 50/50 - 0s - loss: 204.3511 - 102ms/epoch - 2ms/step
# Epoch 43/500
# 50/50 - 0s - loss: 301.4506 - 102ms/epoch - 2ms/step
# Epoch 44/500
# 50/50 - 0s - loss: 215.3482 - 106ms/epoch - 2ms/step
# Epoch 45/500
# 50/50 - 0s - loss: 200.9855 - 102ms/epoch - 2ms/step
# Epoch 46/500
# 50/50 - 0s - loss: 178.7912 - 104ms/epoch - 2ms/step
# Epoch 47/500
# 50/50 - 0s - loss: 201.1462 - 104ms/epoch - 2ms/step
# Epoch 48/500
# 50/50 - 0s - loss: 212.9937 - 101ms/epoch - 2ms/step
# Epoch 49/500
# 50/50 - 0s - loss: 237.7237 - 103ms/epoch - 2ms/step
# Epoch 50/500
# 50/50 - 0s - loss: 206.7369 - 104ms/epoch - 2ms/step
# Epoch 51/500
# 50/50 - 0s - loss: 177.8287 - 103ms/epoch - 2ms/step
# Epoch 52/500
# 50/50 - 0s - loss: 189.0548 - 105ms/epoch - 2ms/step
# Epoch 53/500
# 50/50 - 0s - loss: 181.9165 - 108ms/epoch - 2ms/step
# Epoch 54/500
# 50/50 - 0s - loss: 270.1508 - 110ms/epoch - 2ms/step
# Epoch 55/500
# 50/50 - 0s - loss: 239.7239 - 104ms/epoch - 2ms/step
# Epoch 56/500
# 50/50 - 0s - loss: 234.9153 - 71ms/epoch - 1ms/step
# Epoch 57/500
# 50/50 - 0s - loss: 199.0020 - 76ms/epoch - 2ms/step
# Epoch 58/500
# 50/50 - 0s - loss: 248.6900 - 69ms/epoch - 1ms/step
# Epoch 59/500
# 50/50 - 0s - loss: 208.2209 - 76ms/epoch - 2ms/step
# Epoch 60/500
# 50/50 - 0s - loss: 270.2020 - 70ms/epoch - 1ms/step
# Epoch 61/500
# 50/50 - 0s - loss: 268.1672 - 73ms/epoch - 1ms/step
# Epoch 62/500
# 50/50 - 0s - loss: 309.9442 - 88ms/epoch - 2ms/step
# Epoch 63/500
# 50/50 - 0s - loss: 177.3907 - 72ms/epoch - 1ms/step
# Epoch 64/500
# 50/50 - 0s - loss: 173.0204 - 72ms/epoch - 1ms/step
# Epoch 65/500
# 50/50 - 0s - loss: 147.1804 - 69ms/epoch - 1ms/step
# Epoch 66/500
# 50/50 - 0s - loss: 136.1455 - 69ms/epoch - 1ms/step
# Epoch 67/500
# 50/50 - 0s - loss: 282.9590 - 72ms/epoch - 1ms/step
# Epoch 68/500
# 50/50 - 0s - loss: 157.8714 - 71ms/epoch - 1ms/step
# Epoch 69/500
# 50/50 - 0s - loss: 133.8770 - 71ms/epoch - 1ms/step
# Epoch 70/500
# 50/50 - 0s - loss: 205.0776 - 88ms/epoch - 2ms/step
# Epoch 71/500
# 50/50 - 0s - loss: 131.8347 - 83ms/epoch - 2ms/step
# Epoch 72/500
# 50/50 - 0s - loss: 154.6194 - 72ms/epoch - 1ms/step
# Epoch 73/500
# 50/50 - 0s - loss: 151.2779 - 73ms/epoch - 1ms/step
# Epoch 74/500
# 50/50 - 0s - loss: 139.6310 - 71ms/epoch - 1ms/step
# Epoch 75/500
# 50/50 - 0s - loss: 166.0079 - 81ms/epoch - 2ms/step
# Epoch 76/500
# 50/50 - 0s - loss: 163.3860 - 74ms/epoch - 1ms/step
# Epoch 77/500
# 50/50 - 0s - loss: 158.9957 - 75ms/epoch - 2ms/step
# Epoch 78/500
# 50/50 - 0s - loss: 207.6583 - 80ms/epoch - 2ms/step
# Epoch 79/500
# 50/50 - 0s - loss: 212.0799 - 74ms/epoch - 1ms/step
# Epoch 80/500
# 50/50 - 0s - loss: 143.0788 - 74ms/epoch - 1ms/step
# Epoch 81/500
# 50/50 - 0s - loss: 151.9152 - 72ms/epoch - 1ms/step
# Epoch 82/500
# 50/50 - 0s - loss: 183.4445 - 75ms/epoch - 2ms/step
# Epoch 83/500
# 50/50 - 0s - loss: 167.7349 - 76ms/epoch - 2ms/step
# Epoch 84/500
# 50/50 - 0s - loss: 161.5539 - 76ms/epoch - 2ms/step
# Epoch 85/500
# 50/50 - 0s - loss: 214.2756 - 80ms/epoch - 2ms/step
# Epoch 86/500
# 50/50 - 0s - loss: 169.2453 - 72ms/epoch - 1ms/step
# Epoch 87/500
# 50/50 - 0s - loss: 170.8839 - 72ms/epoch - 1ms/step
# Epoch 88/500
# 50/50 - 0s - loss: 148.0905 - 74ms/epoch - 1ms/step
# Epoch 89/500
# 50/50 - 0s - loss: 148.4880 - 73ms/epoch - 1ms/step
# Epoch 90/500
# 50/50 - 0s - loss: 118.2308 - 78ms/epoch - 2ms/step
# Epoch 91/500
# 50/50 - 0s - loss: 154.6910 - 72ms/epoch - 1ms/step
# Epoch 92/500
# 50/50 - 0s - loss: 122.2757 - 73ms/epoch - 1ms/step
# Epoch 93/500
# 50/50 - 0s - loss: 115.8417 - 77ms/epoch - 2ms/step
# Epoch 94/500
# 50/50 - 0s - loss: 158.4599 - 72ms/epoch - 1ms/step
# Epoch 95/500
# 50/50 - 0s - loss: 177.4993 - 70ms/epoch - 1ms/step
# Epoch 96/500
# 50/50 - 0s - loss: 149.1686 - 71ms/epoch - 1ms/step
# Epoch 97/500
# 50/50 - 0s - loss: 189.4740 - 70ms/epoch - 1ms/step
# Epoch 98/500
# 50/50 - 0s - loss: 113.0406 - 77ms/epoch - 2ms/step
# Epoch 99/500
# 50/50 - 0s - loss: 154.3741 - 70ms/epoch - 1ms/step
# Epoch 100/500
# 50/50 - 0s - loss: 137.0217 - 72ms/epoch - 1ms/step
# Epoch 101/500
# 50/50 - 0s - loss: 151.2406 - 81ms/epoch - 2ms/step
# Epoch 102/500
# 50/50 - 0s - loss: 165.5560 - 75ms/epoch - 2ms/step
# Epoch 103/500
# 50/50 - 0s - loss: 162.6151 - 76ms/epoch - 2ms/step
# Epoch 104/500
# 50/50 - 0s - loss: 126.6458 - 79ms/epoch - 2ms/step
# Epoch 105/500
# 50/50 - 0s - loss: 191.8874 - 71ms/epoch - 1ms/step
# Epoch 106/500
# 50/50 - 0s - loss: 128.1386 - 71ms/epoch - 1ms/step
# Epoch 107/500
# 50/50 - 0s - loss: 113.0188 - 75ms/epoch - 2ms/step
# Epoch 108/500
# 50/50 - 0s - loss: 135.4156 - 72ms/epoch - 1ms/step
# Epoch 109/500
# 50/50 - 0s - loss: 173.2413 - 76ms/epoch - 2ms/step
# Epoch 110/500
# 50/50 - 0s - loss: 112.3895 - 72ms/epoch - 1ms/step
# Epoch 111/500
# 50/50 - 0s - loss: 136.1664 - 73ms/epoch - 1ms/step
# Epoch 112/500
# 50/50 - 0s - loss: 165.1684 - 74ms/epoch - 1ms/step
# Epoch 113/500
# 50/50 - 0s - loss: 166.2372 - 72ms/epoch - 1ms/step
# Epoch 114/500
# 50/50 - 0s - loss: 163.3403 - 78ms/epoch - 2ms/step
# Epoch 115/500
# 50/50 - 0s - loss: 170.7419 - 79ms/epoch - 2ms/step
# Epoch 116/500
# 50/50 - 0s - loss: 149.9543 - 74ms/epoch - 1ms/step
# Epoch 117/500
# 50/50 - 0s - loss: 139.4142 - 75ms/epoch - 2ms/step
# Epoch 118/500
# 50/50 - 0s - loss: 119.0915 - 68ms/epoch - 1ms/step
# Epoch 119/500
# 50/50 - 0s - loss: 173.0308 - 69ms/epoch - 1ms/step
# Epoch 120/500
# 50/50 - 0s - loss: 201.7100 - 71ms/epoch - 1ms/step
# Epoch 121/500
# 50/50 - 0s - loss: 144.8650 - 70ms/epoch - 1ms/step
# Epoch 122/500
# 50/50 - 0s - loss: 196.7527 - 71ms/epoch - 1ms/step
# Epoch 123/500
# 50/50 - 0s - loss: 239.5334 - 79ms/epoch - 2ms/step
# Epoch 124/500
# 50/50 - 0s - loss: 156.4499 - 70ms/epoch - 1ms/step
# Epoch 125/500
# 50/50 - 0s - loss: 118.6011 - 73ms/epoch - 1ms/step
# Epoch 126/500
# 50/50 - 0s - loss: 94.2900 - 74ms/epoch - 1ms/step
# Epoch 127/500
# 50/50 - 0s - loss: 133.0950 - 73ms/epoch - 1ms/step
# Epoch 128/500
# 50/50 - 0s - loss: 185.7610 - 81ms/epoch - 2ms/step
# Epoch 129/500
# 50/50 - 0s - loss: 122.4263 - 76ms/epoch - 2ms/step
# Epoch 130/500
# 50/50 - 0s - loss: 162.8328 - 73ms/epoch - 1ms/step
# Epoch 131/500
# 50/50 - 0s - loss: 132.4052 - 72ms/epoch - 1ms/step
# Epoch 132/500
# 50/50 - 0s - loss: 124.1195 - 71ms/epoch - 1ms/step
# Epoch 133/500
# 50/50 - 0s - loss: 137.6921 - 78ms/epoch - 2ms/step
# Epoch 134/500
# 50/50 - 0s - loss: 119.7389 - 71ms/epoch - 1ms/step
# Epoch 135/500
# 50/50 - 0s - loss: 143.2551 - 72ms/epoch - 1ms/step
# Epoch 136/500
# 50/50 - 0s - loss: 118.0122 - 74ms/epoch - 1ms/step
# Epoch 137/500
# 50/50 - 0s - loss: 103.4680 - 75ms/epoch - 1ms/step
# Epoch 138/500
# 50/50 - 0s - loss: 104.3676 - 70ms/epoch - 1ms/step
# Epoch 139/500
# 50/50 - 0s - loss: 111.7608 - 68ms/epoch - 1ms/step
# Epoch 140/500
# 50/50 - 0s - loss: 115.1625 - 82ms/epoch - 2ms/step
# Epoch 141/500
# 50/50 - 0s - loss: 119.1516 - 81ms/epoch - 2ms/step
# Epoch 142/500
# 50/50 - 0s - loss: 118.0159 - 76ms/epoch - 2ms/step
# Epoch 143/500
# 50/50 - 0s - loss: 134.2148 - 73ms/epoch - 1ms/step
# Epoch 144/500
# 50/50 - 0s - loss: 102.6995 - 75ms/epoch - 2ms/step
# Epoch 145/500
# 50/50 - 0s - loss: 119.2933 - 73ms/epoch - 1ms/step
# Epoch 146/500
# 50/50 - 0s - loss: 94.8841 - 75ms/epoch - 1ms/step
# Epoch 147/500
# 50/50 - 0s - loss: 162.3079 - 72ms/epoch - 1ms/step
# Epoch 148/500
# 50/50 - 0s - loss: 123.9724 - 72ms/epoch - 1ms/step
# Epoch 149/500
# 50/50 - 0s - loss: 120.4080 - 81ms/epoch - 2ms/step
# Epoch 150/500
# 50/50 - 0s - loss: 115.6213 - 73ms/epoch - 1ms/step
# Epoch 151/500
# 50/50 - 0s - loss: 171.8557 - 77ms/epoch - 2ms/step
# Epoch 152/500
# 50/50 - 0s - loss: 170.3448 - 70ms/epoch - 1ms/step
# Epoch 153/500
# 50/50 - 0s - loss: 141.4322 - 70ms/epoch - 1ms/step
# Epoch 154/500
# 50/50 - 0s - loss: 170.3401 - 76ms/epoch - 2ms/step
# Epoch 155/500
# 50/50 - 0s - loss: 137.2831 - 72ms/epoch - 1ms/step
# Epoch 156/500
# 50/50 - 0s - loss: 142.2010 - 74ms/epoch - 1ms/step
# Epoch 157/500
# 50/50 - 0s - loss: 124.2075 - 77ms/epoch - 2ms/step
# Epoch 158/500
# 50/50 - 0s - loss: 127.0959 - 73ms/epoch - 1ms/step
# Epoch 159/500
# 50/50 - 0s - loss: 128.7066 - 75ms/epoch - 2ms/step
# Epoch 160/500
# 50/50 - 0s - loss: 113.5941 - 81ms/epoch - 2ms/step
# Epoch 161/500
# 50/50 - 0s - loss: 92.4722 - 79ms/epoch - 2ms/step
# Epoch 162/500
# 50/50 - 0s - loss: 148.5425 - 73ms/epoch - 1ms/step
# Epoch 163/500
# 50/50 - 0s - loss: 219.2072 - 74ms/epoch - 1ms/step
# Epoch 164/500
# 50/50 - 0s - loss: 142.2075 - 72ms/epoch - 1ms/step
# Epoch 165/500
# 50/50 - 0s - loss: 122.5799 - 75ms/epoch - 2ms/step
# Epoch 166/500
# 50/50 - 0s - loss: 122.0090 - 72ms/epoch - 1ms/step
# Epoch 167/500
# 50/50 - 0s - loss: 133.3909 - 84ms/epoch - 2ms/step
# Epoch 168/500
# 50/50 - 0s - loss: 108.0462 - 74ms/epoch - 1ms/step
# Epoch 169/500
# 50/50 - 0s - loss: 89.6178 - 72ms/epoch - 1ms/step
# Epoch 170/500
# 50/50 - 0s - loss: 112.4339 - 72ms/epoch - 1ms/step
# Epoch 171/500
# 50/50 - 0s - loss: 105.2336 - 73ms/epoch - 1ms/step
# Epoch 172/500
# 50/50 - 0s - loss: 95.1503 - 70ms/epoch - 1ms/step
# Epoch 173/500
# 50/50 - 0s - loss: 108.0420 - 81ms/epoch - 2ms/step
# Epoch 174/500
# 50/50 - 0s - loss: 124.1382 - 70ms/epoch - 1ms/step
# Epoch 175/500
# 50/50 - 0s - loss: 143.4222 - 72ms/epoch - 1ms/step
# Epoch 176/500
# 50/50 - 0s - loss: 148.1000 - 70ms/epoch - 1ms/step
# Epoch 177/500
# 50/50 - 0s - loss: 120.0090 - 73ms/epoch - 1ms/step
# Epoch 178/500
# 50/50 - 0s - loss: 135.7802 - 79ms/epoch - 2ms/step
# Epoch 179/500
# 50/50 - 0s - loss: 127.5590 - 76ms/epoch - 2ms/step
# Epoch 180/500
# 50/50 - 0s - loss: 161.1940 - 80ms/epoch - 2ms/step
# Epoch 181/500
# 50/50 - 0s - loss: 107.9925 - 74ms/epoch - 1ms/step
# Epoch 182/500
# 50/50 - 0s - loss: 138.6920 - 75ms/epoch - 2ms/step
# Epoch 183/500
# 50/50 - 0s - loss: 173.4678 - 78ms/epoch - 2ms/step
# Epoch 184/500
# 50/50 - 0s - loss: 109.7753 - 72ms/epoch - 1ms/step
# Epoch 185/500
# 50/50 - 0s - loss: 90.8265 - 105ms/epoch - 2ms/step
# Epoch 186/500
# 50/50 - 0s - loss: 93.5496 - 109ms/epoch - 2ms/step
# Epoch 187/500
# 50/50 - 0s - loss: 111.6719 - 106ms/epoch - 2ms/step
# Epoch 188/500
# 50/50 - 0s - loss: 111.3251 - 115ms/epoch - 2ms/step
# Epoch 189/500
# 50/50 - 0s - loss: 120.0021 - 103ms/epoch - 2ms/step
# Epoch 190/500
# 50/50 - 0s - loss: 147.8452 - 102ms/epoch - 2ms/step
# Epoch 191/500
# 50/50 - 0s - loss: 114.3449 - 117ms/epoch - 2ms/step
# Epoch 192/500
# 50/50 - 0s - loss: 125.0411 - 105ms/epoch - 2ms/step
# Epoch 193/500
# 50/50 - 0s - loss: 105.9799 - 104ms/epoch - 2ms/step
# Epoch 194/500
# 50/50 - 0s - loss: 102.1409 - 100ms/epoch - 2ms/step
# Epoch 195/500
# 50/50 - 0s - loss: 325.1346 - 102ms/epoch - 2ms/step
# Epoch 196/500
# 50/50 - 0s - loss: 116.1959 - 103ms/epoch - 2ms/step
# Epoch 197/500
# 50/50 - 0s - loss: 87.6993 - 103ms/epoch - 2ms/step
# Epoch 198/500
# 50/50 - 0s - loss: 116.3797 - 115ms/epoch - 2ms/step
# Epoch 199/500
# 50/50 - 0s - loss: 77.4759 - 101ms/epoch - 2ms/step
# Epoch 200/500
# 50/50 - 0s - loss: 74.5293 - 120ms/epoch - 2ms/step
# Epoch 201/500
# 50/50 - 0s - loss: 111.3744 - 103ms/epoch - 2ms/step
# Epoch 202/500
# 50/50 - 0s - loss: 161.5874 - 101ms/epoch - 2ms/step
# Epoch 203/500
# 50/50 - 0s - loss: 131.7619 - 104ms/epoch - 2ms/step
# Epoch 204/500
# 50/50 - 0s - loss: 162.9125 - 100ms/epoch - 2ms/step
# Epoch 205/500
# 50/50 - 0s - loss: 201.3185 - 102ms/epoch - 2ms/step
# Epoch 206/500
# 50/50 - 0s - loss: 103.6622 - 100ms/epoch - 2ms/step
# Epoch 207/500
# 50/50 - 0s - loss: 92.3352 - 98ms/epoch - 2ms/step
# Epoch 208/500
# 50/50 - 0s - loss: 78.2974 - 100ms/epoch - 2ms/step
# Epoch 209/500
# 50/50 - 0s - loss: 112.4602 - 121ms/epoch - 2ms/step
# Epoch 210/500
# 50/50 - 0s - loss: 99.3684 - 107ms/epoch - 2ms/step
# Epoch 211/500
# 50/50 - 0s - loss: 116.2904 - 85ms/epoch - 2ms/step
# Epoch 212/500
# 50/50 - 0s - loss: 111.3621 - 75ms/epoch - 2ms/step
# Epoch 213/500
# 50/50 - 0s - loss: 86.0076 - 71ms/epoch - 1ms/step
# Epoch 214/500
# 50/50 - 0s - loss: 106.4286 - 69ms/epoch - 1ms/step
# Epoch 215/500
# 50/50 - 0s - loss: 79.2796 - 74ms/epoch - 1ms/step
# Epoch 216/500
# 50/50 - 0s - loss: 90.9610 - 76ms/epoch - 2ms/step
# Epoch 217/500
# 50/50 - 0s - loss: 126.7812 - 74ms/epoch - 1ms/step
# Epoch 218/500
# 50/50 - 0s - loss: 107.2143 - 73ms/epoch - 1ms/step
# Epoch 219/500
# 50/50 - 0s - loss: 97.4530 - 73ms/epoch - 1ms/step
# Epoch 220/500
# 50/50 - 0s - loss: 94.2257 - 71ms/epoch - 1ms/step
# Epoch 221/500
# 50/50 - 0s - loss: 74.4261 - 69ms/epoch - 1ms/step
# Epoch 222/500
# 50/50 - 0s - loss: 87.2125 - 84ms/epoch - 2ms/step
# Epoch 223/500
# 50/50 - 0s - loss: 97.4141 - 81ms/epoch - 2ms/step
# Epoch 224/500
# 50/50 - 0s - loss: 104.8277 - 73ms/epoch - 1ms/step
# Epoch 225/500
# 50/50 - 0s - loss: 84.5562 - 72ms/epoch - 1ms/step
# Epoch 226/500
# 50/50 - 0s - loss: 77.0317 - 72ms/epoch - 1ms/step
# Epoch 227/500
# 50/50 - 0s - loss: 88.4473 - 74ms/epoch - 1ms/step
# Epoch 228/500
# 50/50 - 0s - loss: 76.4917 - 75ms/epoch - 1ms/step
# Epoch 229/500
# 50/50 - 0s - loss: 91.4345 - 73ms/epoch - 1ms/step
# Epoch 230/500
# 50/50 - 0s - loss: 94.6517 - 74ms/epoch - 1ms/step
# Epoch 231/500
# 50/50 - 0s - loss: 76.5471 - 74ms/epoch - 1ms/step
# Epoch 232/500
# 50/50 - 0s - loss: 118.5455 - 79ms/epoch - 2ms/step
# Epoch 233/500
# 50/50 - 0s - loss: 82.5117 - 75ms/epoch - 1ms/step
# Epoch 234/500
# 50/50 - 0s - loss: 119.0418 - 76ms/epoch - 2ms/step
# Epoch 235/500
# 50/50 - 0s - loss: 109.0683 - 77ms/epoch - 2ms/step
# Epoch 236/500
# 50/50 - 0s - loss: 156.0961 - 81ms/epoch - 2ms/step
# Epoch 237/500
# 50/50 - 0s - loss: 121.7429 - 71ms/epoch - 1ms/step
# Epoch 238/500
# 50/50 - 0s - loss: 71.4293 - 79ms/epoch - 2ms/step
# Epoch 239/500
# 50/50 - 0s - loss: 71.2597 - 72ms/epoch - 1ms/step
# Epoch 240/500
# 50/50 - 0s - loss: 102.9513 - 72ms/epoch - 1ms/step
# Epoch 241/500
# 50/50 - 0s - loss: 181.7947 - 74ms/epoch - 1ms/step
# Epoch 242/500
# 50/50 - 0s - loss: 232.6245 - 78ms/epoch - 2ms/step
# Epoch 243/500
# 50/50 - 0s - loss: 155.8135 - 77ms/epoch - 2ms/step
# Epoch 244/500
# 50/50 - 0s - loss: 130.2858 - 78ms/epoch - 2ms/step
# Epoch 245/500
# 50/50 - 0s - loss: 126.8276 - 74ms/epoch - 1ms/step
# Epoch 246/500
# 50/50 - 0s - loss: 179.5818 - 76ms/epoch - 2ms/step
# Epoch 247/500
# 50/50 - 0s - loss: 101.8391 - 73ms/epoch - 1ms/step
# Epoch 248/500
# 50/50 - 0s - loss: 110.0441 - 70ms/epoch - 1ms/step
# Epoch 249/500
# 50/50 - 0s - loss: 85.4713 - 87ms/epoch - 2ms/step
# Epoch 250/500
# 50/50 - 0s - loss: 112.1031 - 72ms/epoch - 1ms/step
# Epoch 251/500
# 50/50 - 0s - loss: 83.8203 - 73ms/epoch - 1ms/step
# Epoch 252/500
# 50/50 - 0s - loss: 84.7832 - 71ms/epoch - 1ms/step
# Epoch 253/500
# 50/50 - 0s - loss: 72.5873 - 71ms/epoch - 1ms/step
# Epoch 254/500
# 50/50 - 0s - loss: 147.4624 - 81ms/epoch - 2ms/step
# Epoch 255/500
# 50/50 - 0s - loss: 78.6511 - 75ms/epoch - 2ms/step
# Epoch 256/500
# 50/50 - 0s - loss: 78.8036 - 72ms/epoch - 1ms/step
# Epoch 257/500
# 50/50 - 0s - loss: 77.3208 - 75ms/epoch - 1ms/step
# Epoch 258/500
# 50/50 - 0s - loss: 124.3625 - 74ms/epoch - 1ms/step
# Epoch 259/500
# 50/50 - 0s - loss: 88.2452 - 81ms/epoch - 2ms/step
# Epoch 260/500
# 50/50 - 0s - loss: 97.1069 - 78ms/epoch - 2ms/step
# Epoch 261/500
# 50/50 - 0s - loss: 90.6752 - 74ms/epoch - 1ms/step
# Epoch 262/500
# 50/50 - 0s - loss: 131.2213 - 78ms/epoch - 2ms/step
# Epoch 263/500
# 50/50 - 0s - loss: 96.2664 - 72ms/epoch - 1ms/step
# Epoch 264/500
# 50/50 - 0s - loss: 77.7517 - 72ms/epoch - 1ms/step
# Epoch 265/500
# 50/50 - 0s - loss: 98.5535 - 72ms/epoch - 1ms/step
# Epoch 266/500
# 50/50 - 0s - loss: 101.2487 - 79ms/epoch - 2ms/step
# Epoch 267/500
# 50/50 - 0s - loss: 100.5542 - 73ms/epoch - 1ms/step
# Epoch 268/500
# 50/50 - 0s - loss: 77.2855 - 72ms/epoch - 1ms/step
# Epoch 269/500
# 50/50 - 0s - loss: 87.6477 - 78ms/epoch - 2ms/step
# Epoch 270/500
# 50/50 - 0s - loss: 78.7629 - 72ms/epoch - 1ms/step
# Epoch 271/500
# 50/50 - 0s - loss: 88.9960 - 71ms/epoch - 1ms/step
# Epoch 272/500
# 50/50 - 0s - loss: 78.4732 - 70ms/epoch - 1ms/step
# Epoch 273/500
# 50/50 - 0s - loss: 84.3565 - 85ms/epoch - 2ms/step
# Epoch 274/500
# 50/50 - 0s - loss: 91.4874 - 84ms/epoch - 2ms/step
# Epoch 275/500
# 50/50 - 0s - loss: 86.2570 - 77ms/epoch - 2ms/step
# Epoch 276/500
# 50/50 - 0s - loss: 89.7563 - 72ms/epoch - 1ms/step
# Epoch 277/500
# 50/50 - 0s - loss: 83.7915 - 71ms/epoch - 1ms/step
# Epoch 278/500
# 50/50 - 0s - loss: 168.6065 - 69ms/epoch - 1ms/step
# Epoch 279/500
# 50/50 - 0s - loss: 152.9825 - 72ms/epoch - 1ms/step
# Epoch 280/500
# 50/50 - 0s - loss: 93.7663 - 74ms/epoch - 1ms/step
# Epoch 281/500
# 50/50 - 0s - loss: 143.7984 - 74ms/epoch - 1ms/step
# Epoch 282/500
# 50/50 - 0s - loss: 98.4913 - 72ms/epoch - 1ms/step
# Epoch 283/500
# 50/50 - 0s - loss: 80.5724 - 72ms/epoch - 1ms/step
# Epoch 284/500
# 50/50 - 0s - loss: 79.3959 - 76ms/epoch - 2ms/step
# Epoch 285/500
# 50/50 - 0s - loss: 87.0622 - 73ms/epoch - 1ms/step
# Epoch 286/500
# 50/50 - 0s - loss: 85.5056 - 77ms/epoch - 2ms/step
# Epoch 287/500
# 50/50 - 0s - loss: 102.3104 - 74ms/epoch - 1ms/step
# Epoch 288/500
# 50/50 - 0s - loss: 72.1099 - 82ms/epoch - 2ms/step
# Epoch 289/500
# 50/50 - 0s - loss: 197.0345 - 73ms/epoch - 1ms/step
# Epoch 290/500
# 50/50 - 0s - loss: 95.5851 - 81ms/epoch - 2ms/step
# Epoch 291/500
# 50/50 - 0s - loss: 107.4121 - 72ms/epoch - 1ms/step
# Epoch 292/500
# 50/50 - 0s - loss: 71.1919 - 75ms/epoch - 1ms/step
# Epoch 293/500
# 50/50 - 0s - loss: 89.0675 - 75ms/epoch - 2ms/step
# Epoch 294/500
# 50/50 - 0s - loss: 77.5167 - 72ms/epoch - 1ms/step
# Epoch 295/500
# 50/50 - 0s - loss: 92.2861 - 73ms/epoch - 1ms/step
# Epoch 296/500
# 50/50 - 0s - loss: 99.7054 - 74ms/epoch - 1ms/step
# Epoch 297/500
# 50/50 - 0s - loss: 82.7056 - 72ms/epoch - 1ms/step
# Epoch 298/500
# 50/50 - 0s - loss: 80.0007 - 72ms/epoch - 1ms/step
# Epoch 299/500
# 50/50 - 0s - loss: 67.7172 - 74ms/epoch - 1ms/step
# Epoch 300/500
# 50/50 - 0s - loss: 88.0256 - 70ms/epoch - 1ms/step
# Epoch 301/500
# 50/50 - 0s - loss: 90.0916 - 75ms/epoch - 2ms/step
# Epoch 302/500
# 50/50 - 0s - loss: 112.7220 - 74ms/epoch - 1ms/step
# Epoch 303/500
# 50/50 - 0s - loss: 151.1417 - 78ms/epoch - 2ms/step
# Epoch 304/500
# 50/50 - 0s - loss: 83.2587 - 72ms/epoch - 1ms/step
# Epoch 305/500
# 50/50 - 0s - loss: 81.2937 - 75ms/epoch - 1ms/step
# Epoch 306/500
# 50/50 - 0s - loss: 78.6699 - 71ms/epoch - 1ms/step
# Epoch 307/500
# 50/50 - 0s - loss: 73.9870 - 71ms/epoch - 1ms/step
# Epoch 308/500
# 50/50 - 0s - loss: 72.6504 - 80ms/epoch - 2ms/step
# Epoch 309/500
# 50/50 - 0s - loss: 69.7379 - 73ms/epoch - 1ms/step
# Epoch 310/500
# 50/50 - 0s - loss: 110.9807 - 72ms/epoch - 1ms/step
# Epoch 311/500
# 50/50 - 0s - loss: 114.2923 - 77ms/epoch - 2ms/step
# Epoch 312/500
# 50/50 - 0s - loss: 111.8306 - 78ms/epoch - 2ms/step
# Epoch 313/500
# 50/50 - 0s - loss: 66.1160 - 80ms/epoch - 2ms/step
# Epoch 314/500
# 50/50 - 0s - loss: 61.7948 - 73ms/epoch - 1ms/step
# Epoch 315/500
# 50/50 - 0s - loss: 80.0943 - 82ms/epoch - 2ms/step
# Epoch 316/500
# 50/50 - 0s - loss: 104.1944 - 72ms/epoch - 1ms/step
# Epoch 317/500
# 50/50 - 0s - loss: 110.5104 - 72ms/epoch - 1ms/step
# Epoch 318/500
# 50/50 - 0s - loss: 79.9634 - 73ms/epoch - 1ms/step
# Epoch 319/500
# 50/50 - 0s - loss: 92.4633 - 85ms/epoch - 2ms/step
# Epoch 320/500
# 50/50 - 0s - loss: 107.3790 - 71ms/epoch - 1ms/step
# Epoch 321/500
# 50/50 - 0s - loss: 129.6958 - 67ms/epoch - 1ms/step
# Epoch 322/500
# 50/50 - 0s - loss: 137.8770 - 70ms/epoch - 1ms/step
# Epoch 323/500
# 50/50 - 0s - loss: 425.9865 - 72ms/epoch - 1ms/step
# Epoch 324/500
# 50/50 - 0s - loss: 107.0674 - 74ms/epoch - 1ms/step
# Epoch 325/500
# 50/50 - 0s - loss: 98.6572 - 74ms/epoch - 1ms/step
# Epoch 326/500
# 50/50 - 0s - loss: 103.0872 - 91ms/epoch - 2ms/step
# Epoch 327/500
# 50/50 - 0s - loss: 67.7044 - 77ms/epoch - 2ms/step
# Epoch 328/500
# 50/50 - 0s - loss: 92.4193 - 81ms/epoch - 2ms/step
# Epoch 329/500
# 50/50 - 0s - loss: 120.1481 - 72ms/epoch - 1ms/step
# Epoch 330/500
# 50/50 - 0s - loss: 159.7597 - 75ms/epoch - 1ms/step
# Epoch 331/500
# 50/50 - 0s - loss: 183.1742 - 72ms/epoch - 1ms/step
# Epoch 332/500
# 50/50 - 0s - loss: 125.0268 - 77ms/epoch - 2ms/step
# Epoch 333/500
# 50/50 - 0s - loss: 94.8707 - 73ms/epoch - 1ms/step
# Epoch 334/500
# 50/50 - 0s - loss: 80.0557 - 77ms/epoch - 2ms/step
# Epoch 335/500
# 50/50 - 0s - loss: 107.1784 - 73ms/epoch - 1ms/step
# Epoch 336/500
# 50/50 - 0s - loss: 76.7364 - 73ms/epoch - 1ms/step
# Epoch 337/500
# 50/50 - 0s - loss: 66.3368 - 73ms/epoch - 1ms/step
# Epoch 338/500
# 50/50 - 0s - loss: 76.0607 - 76ms/epoch - 2ms/step
# Epoch 339/500
# 50/50 - 0s - loss: 97.8548 - 93ms/epoch - 2ms/step
# Epoch 340/500
# 50/50 - 0s - loss: 69.0412 - 112ms/epoch - 2ms/step
# Epoch 341/500
# 50/50 - 0s - loss: 99.5835 - 107ms/epoch - 2ms/step
# Epoch 342/500
# 50/50 - 0s - loss: 66.2790 - 103ms/epoch - 2ms/step
# Epoch 343/500
# 50/50 - 0s - loss: 73.0053 - 110ms/epoch - 2ms/step
# Epoch 344/500
# 50/50 - 0s - loss: 76.5056 - 110ms/epoch - 2ms/step
# Epoch 345/500
# 50/50 - 0s - loss: 62.1254 - 106ms/epoch - 2ms/step
# Epoch 346/500
# 50/50 - 0s - loss: 72.4732 - 105ms/epoch - 2ms/step
# Epoch 347/500
# 50/50 - 0s - loss: 71.5513 - 111ms/epoch - 2ms/step
# Epoch 348/500
# 50/50 - 0s - loss: 85.5616 - 106ms/epoch - 2ms/step
# Epoch 349/500
# 50/50 - 0s - loss: 65.6952 - 105ms/epoch - 2ms/step
# Epoch 350/500
# 50/50 - 0s - loss: 68.3674 - 97ms/epoch - 2ms/step
# Epoch 351/500
# 50/50 - 0s - loss: 86.3401 - 96ms/epoch - 2ms/step
# Epoch 352/500
# 50/50 - 0s - loss: 92.0372 - 96ms/epoch - 2ms/step
# Epoch 353/500
# 50/50 - 0s - loss: 106.4223 - 91ms/epoch - 2ms/step
# Epoch 354/500
# 50/50 - 0s - loss: 77.7250 - 93ms/epoch - 2ms/step
# Epoch 355/500
# 50/50 - 0s - loss: 81.0175 - 96ms/epoch - 2ms/step
# Epoch 356/500
# 50/50 - 0s - loss: 93.8185 - 97ms/epoch - 2ms/step
# Epoch 357/500
# 50/50 - 0s - loss: 126.9709 - 103ms/epoch - 2ms/step
# Epoch 358/500
# 50/50 - 0s - loss: 113.1950 - 101ms/epoch - 2ms/step
# Epoch 359/500
# 50/50 - 0s - loss: 90.9929 - 102ms/epoch - 2ms/step
# Epoch 360/500
# 50/50 - 0s - loss: 101.3464 - 101ms/epoch - 2ms/step
# Epoch 361/500
# 50/50 - 0s - loss: 84.7645 - 99ms/epoch - 2ms/step
# Epoch 362/500
# 50/50 - 0s - loss: 87.3450 - 97ms/epoch - 2ms/step
# Epoch 363/500
# 50/50 - 0s - loss: 84.9196 - 104ms/epoch - 2ms/step
# Epoch 364/500
# 50/50 - 0s - loss: 81.8735 - 114ms/epoch - 2ms/step
# Epoch 365/500
# 50/50 - 0s - loss: 77.2961 - 112ms/epoch - 2ms/step
# Epoch 366/500
# 50/50 - 0s - loss: 57.5428 - 80ms/epoch - 2ms/step
# Epoch 367/500
# 50/50 - 0s - loss: 114.1581 - 85ms/epoch - 2ms/step
# Epoch 368/500
# 50/50 - 0s - loss: 76.7956 - 76ms/epoch - 2ms/step
# Epoch 369/500
# 50/50 - 0s - loss: 77.9292 - 74ms/epoch - 1ms/step
# Epoch 370/500
# 50/50 - 0s - loss: 86.8270 - 71ms/epoch - 1ms/step
# Epoch 371/500
# 50/50 - 0s - loss: 87.6846 - 87ms/epoch - 2ms/step
# Epoch 372/500
# 50/50 - 0s - loss: 73.9929 - 76ms/epoch - 2ms/step
# Epoch 373/500
# 50/50 - 0s - loss: 79.6183 - 71ms/epoch - 1ms/step
# Epoch 374/500
# 50/50 - 0s - loss: 75.8487 - 72ms/epoch - 1ms/step
# Epoch 375/500
# 50/50 - 0s - loss: 85.4357 - 76ms/epoch - 2ms/step
# Epoch 376/500
# 50/50 - 0s - loss: 102.4211 - 77ms/epoch - 2ms/step
# Epoch 377/500
# 50/50 - 0s - loss: 69.2416 - 74ms/epoch - 1ms/step
# Epoch 378/500
# 50/50 - 0s - loss: 93.8524 - 77ms/epoch - 2ms/step
# Epoch 379/500
# 50/50 - 0s - loss: 136.6434 - 77ms/epoch - 2ms/step
# Epoch 380/500
# 50/50 - 0s - loss: 83.3546 - 73ms/epoch - 1ms/step
# Epoch 381/500
# 50/50 - 0s - loss: 75.3552 - 76ms/epoch - 2ms/step
# Epoch 382/500
# 50/50 - 0s - loss: 69.9418 - 77ms/epoch - 2ms/step
# Epoch 383/500
# 50/50 - 0s - loss: 146.6753 - 84ms/epoch - 2ms/step
# Epoch 384/500
# 50/50 - 0s - loss: 100.9074 - 74ms/epoch - 1ms/step
# Epoch 385/500
# 50/50 - 0s - loss: 93.8413 - 72ms/epoch - 1ms/step
# Epoch 386/500
# 50/50 - 0s - loss: 86.3159 - 75ms/epoch - 1ms/step
# Epoch 387/500
# 50/50 - 0s - loss: 60.1142 - 70ms/epoch - 1ms/step
# Epoch 388/500
# 50/50 - 0s - loss: 60.1043 - 77ms/epoch - 2ms/step
# Epoch 389/500
# 50/50 - 0s - loss: 80.9025 - 72ms/epoch - 1ms/step
# Epoch 390/500
# 50/50 - 0s - loss: 71.6353 - 76ms/epoch - 2ms/step
# Epoch 391/500
# 50/50 - 0s - loss: 79.0404 - 76ms/epoch - 2ms/step
# Epoch 392/500
# 50/50 - 0s - loss: 68.5884 - 75ms/epoch - 2ms/step
# Epoch 393/500
# 50/50 - 0s - loss: 66.4188 - 75ms/epoch - 1ms/step
# Epoch 394/500
# 50/50 - 0s - loss: 71.4655 - 74ms/epoch - 1ms/step
# Epoch 395/500
# 50/50 - 0s - loss: 72.7986 - 72ms/epoch - 1ms/step
# Epoch 396/500
# 50/50 - 0s - loss: 67.9627 - 75ms/epoch - 1ms/step
# Epoch 397/500
# 50/50 - 0s - loss: 113.2321 - 80ms/epoch - 2ms/step
# Epoch 398/500
# 50/50 - 0s - loss: 77.9275 - 77ms/epoch - 2ms/step
# Epoch 399/500
# 50/50 - 0s - loss: 79.3168 - 77ms/epoch - 2ms/step
# Epoch 400/500
# 50/50 - 0s - loss: 71.0759 - 79ms/epoch - 2ms/step
# Epoch 401/500
# 50/50 - 0s - loss: 71.9186 - 80ms/epoch - 2ms/step
# Epoch 402/500
# 50/50 - 0s - loss: 107.2029 - 77ms/epoch - 2ms/step
# Epoch 403/500
# 50/50 - 0s - loss: 70.5086 - 75ms/epoch - 2ms/step
# Epoch 404/500
# 50/50 - 0s - loss: 100.1427 - 74ms/epoch - 1ms/step
# Epoch 405/500
# 50/50 - 0s - loss: 87.0670 - 79ms/epoch - 2ms/step
# Epoch 406/500
# 50/50 - 0s - loss: 78.5437 - 72ms/epoch - 1ms/step
# Epoch 407/500
# 50/50 - 0s - loss: 58.2100 - 77ms/epoch - 2ms/step
# Epoch 408/500
# 50/50 - 0s - loss: 84.1042 - 74ms/epoch - 1ms/step
# Epoch 409/500
# 50/50 - 0s - loss: 58.2166 - 82ms/epoch - 2ms/step
# Epoch 410/500
# 50/50 - 0s - loss: 58.3011 - 75ms/epoch - 2ms/step
# Epoch 411/500
# 50/50 - 0s - loss: 64.8899 - 77ms/epoch - 2ms/step
# Epoch 412/500
# 50/50 - 0s - loss: 72.0882 - 73ms/epoch - 1ms/step
# Epoch 413/500
# 50/50 - 0s - loss: 80.7874 - 75ms/epoch - 1ms/step
# Epoch 414/500
# 50/50 - 0s - loss: 88.1317 - 72ms/epoch - 1ms/step
# Epoch 415/500
# 50/50 - 0s - loss: 66.8312 - 72ms/epoch - 1ms/step
# Epoch 416/500
# 50/50 - 0s - loss: 70.6867 - 78ms/epoch - 2ms/step
# Epoch 417/500
# 50/50 - 0s - loss: 59.5806 - 73ms/epoch - 1ms/step
# Epoch 418/500
# 50/50 - 0s - loss: 104.4619 - 70ms/epoch - 1ms/step
# Epoch 419/500
# 50/50 - 0s - loss: 71.8159 - 82ms/epoch - 2ms/step
# Epoch 420/500
# 50/50 - 0s - loss: 111.3830 - 72ms/epoch - 1ms/step
# Epoch 421/500
# 50/50 - 0s - loss: 333.3806 - 73ms/epoch - 1ms/step
# Epoch 422/500
# 50/50 - 0s - loss: 151.2052 - 74ms/epoch - 1ms/step
# Epoch 423/500
# 50/50 - 0s - loss: 145.1812 - 79ms/epoch - 2ms/step
# Epoch 424/500
# 50/50 - 0s - loss: 113.5596 - 78ms/epoch - 2ms/step
# Epoch 425/500
# 50/50 - 0s - loss: 122.2106 - 74ms/epoch - 1ms/step
# Epoch 426/500
# 50/50 - 0s - loss: 76.6951 - 75ms/epoch - 2ms/step
# Epoch 427/500
# 50/50 - 0s - loss: 90.5365 - 77ms/epoch - 2ms/step
# Epoch 428/500
# 50/50 - 0s - loss: 92.6423 - 80ms/epoch - 2ms/step
# Epoch 429/500
# 50/50 - 0s - loss: 66.8437 - 76ms/epoch - 2ms/step
# Epoch 430/500
# 50/50 - 0s - loss: 97.0147 - 76ms/epoch - 2ms/step
# Epoch 431/500
# 50/50 - 0s - loss: 60.9753 - 76ms/epoch - 2ms/step
# Epoch 432/500
# 50/50 - 0s - loss: 73.8631 - 78ms/epoch - 2ms/step
# Epoch 433/500
# 50/50 - 0s - loss: 98.6884 - 80ms/epoch - 2ms/step
# Epoch 434/500
# 50/50 - 0s - loss: 66.6736 - 72ms/epoch - 1ms/step
# Epoch 435/500
# 50/50 - 0s - loss: 62.8010 - 81ms/epoch - 2ms/step
# Epoch 436/500
# 50/50 - 0s - loss: 67.8256 - 74ms/epoch - 1ms/step
# Epoch 437/500
# 50/50 - 0s - loss: 71.6484 - 74ms/epoch - 1ms/step
# Epoch 438/500
# 50/50 - 0s - loss: 50.1595 - 80ms/epoch - 2ms/step
# Epoch 439/500
# 50/50 - 0s - loss: 74.5585 - 78ms/epoch - 2ms/step
# Epoch 440/500
# 50/50 - 0s - loss: 73.0968 - 75ms/epoch - 2ms/step
# Epoch 441/500
# 50/50 - 0s - loss: 72.4962 - 74ms/epoch - 1ms/step
# Epoch 442/500
# 50/50 - 0s - loss: 111.2243 - 73ms/epoch - 1ms/step
# Epoch 443/500
# 50/50 - 0s - loss: 77.9272 - 73ms/epoch - 1ms/step
# Epoch 444/500
# 50/50 - 0s - loss: 211.0534 - 77ms/epoch - 2ms/step
# Epoch 445/500
# 50/50 - 0s - loss: 172.5599 - 75ms/epoch - 1ms/step
# Epoch 446/500
# 50/50 - 0s - loss: 114.3430 - 75ms/epoch - 1ms/step
# Epoch 447/500
# 50/50 - 0s - loss: 93.6237 - 73ms/epoch - 1ms/step
# Epoch 448/500
# 50/50 - 0s - loss: 79.0074 - 103ms/epoch - 2ms/step
# Epoch 449/500
# 50/50 - 0s - loss: 66.3843 - 74ms/epoch - 1ms/step
# Epoch 450/500
# 50/50 - 0s - loss: 98.1088 - 83ms/epoch - 2ms/step
# Epoch 451/500
# 50/50 - 0s - loss: 54.4011 - 73ms/epoch - 1ms/step
# Epoch 452/500
# 50/50 - 0s - loss: 75.0524 - 77ms/epoch - 2ms/step
# Epoch 453/500
# 50/50 - 0s - loss: 83.9565 - 74ms/epoch - 1ms/step
# Epoch 454/500
# 50/50 - 0s - loss: 61.4821 - 84ms/epoch - 2ms/step
# Epoch 455/500
# 50/50 - 0s - loss: 58.1134 - 75ms/epoch - 2ms/step
# Epoch 456/500
# 50/50 - 0s - loss: 77.1967 - 74ms/epoch - 1ms/step
# Epoch 457/500
# 50/50 - 0s - loss: 51.8161 - 74ms/epoch - 1ms/step
# Epoch 458/500
# 50/50 - 0s - loss: 73.3071 - 77ms/epoch - 2ms/step
# Epoch 459/500
# 50/50 - 0s - loss: 81.3772 - 81ms/epoch - 2ms/step
# Epoch 460/500
# 50/50 - 0s - loss: 61.8730 - 77ms/epoch - 2ms/step
# Epoch 461/500
# 50/50 - 0s - loss: 74.5238 - 75ms/epoch - 1ms/step
# Epoch 462/500
# 50/50 - 0s - loss: 57.6709 - 74ms/epoch - 1ms/step
# Epoch 463/500
# 50/50 - 0s - loss: 50.1307 - 83ms/epoch - 2ms/step
# Epoch 464/500
# 50/50 - 0s - loss: 63.5159 - 76ms/epoch - 2ms/step
# Epoch 465/500
# 50/50 - 0s - loss: 144.5732 - 75ms/epoch - 2ms/step
# Epoch 466/500
# 50/50 - 0s - loss: 87.2567 - 74ms/epoch - 1ms/step
# Epoch 467/500
# 50/50 - 0s - loss: 81.7503 - 76ms/epoch - 2ms/step
# Epoch 468/500
# 50/50 - 0s - loss: 65.8803 - 72ms/epoch - 1ms/step
# Epoch 469/500
# 50/50 - 0s - loss: 76.6609 - 75ms/epoch - 1ms/step
# Epoch 470/500
# 50/50 - 0s - loss: 122.6508 - 76ms/epoch - 2ms/step
# Epoch 471/500
# 50/50 - 0s - loss: 122.1807 - 76ms/epoch - 2ms/step
# Epoch 472/500
# 50/50 - 0s - loss: 71.0752 - 71ms/epoch - 1ms/step
# Epoch 473/500
# 50/50 - 0s - loss: 130.7760 - 77ms/epoch - 2ms/step
# Epoch 474/500
# 50/50 - 0s - loss: 83.1620 - 72ms/epoch - 1ms/step
# Epoch 475/500
# 50/50 - 0s - loss: 66.7995 - 71ms/epoch - 1ms/step
# Epoch 476/500
# 50/50 - 0s - loss: 76.0973 - 79ms/epoch - 2ms/step
# Epoch 477/500
# 50/50 - 0s - loss: 122.4558 - 78ms/epoch - 2ms/step
# Epoch 478/500
# 50/50 - 0s - loss: 67.7297 - 75ms/epoch - 1ms/step
# Epoch 479/500
# 50/50 - 0s - loss: 59.1591 - 74ms/epoch - 1ms/step
# Epoch 480/500
# 50/50 - 0s - loss: 57.2485 - 75ms/epoch - 1ms/step
# Epoch 481/500
# 50/50 - 0s - loss: 62.9828 - 78ms/epoch - 2ms/step
# Epoch 482/500
# 50/50 - 0s - loss: 61.8767 - 75ms/epoch - 1ms/step
# Epoch 483/500
# 50/50 - 0s - loss: 60.4803 - 73ms/epoch - 1ms/step
# Epoch 484/500
# 50/50 - 0s - loss: 51.3101 - 75ms/epoch - 2ms/step
# Epoch 485/500
# 50/50 - 0s - loss: 65.6790 - 72ms/epoch - 1ms/step
# Epoch 486/500
# 50/50 - 0s - loss: 78.8952 - 91ms/epoch - 2ms/step
# Epoch 487/500
# 50/50 - 0s - loss: 76.6346 - 76ms/epoch - 2ms/step
# Epoch 488/500
# 50/50 - 0s - loss: 101.0896 - 73ms/epoch - 1ms/step
# Epoch 489/500
# 50/50 - 0s - loss: 97.8564 - 72ms/epoch - 1ms/step
# Epoch 490/500
# 50/50 - 0s - loss: 116.1177 - 74ms/epoch - 1ms/step
# Epoch 491/500
# 50/50 - 0s - loss: 54.6511 - 80ms/epoch - 2ms/step
# Epoch 492/500
# 50/50 - 0s - loss: 59.3396 - 110ms/epoch - 2ms/step
# Epoch 493/500
# 50/50 - 0s - loss: 58.2261 - 103ms/epoch - 2ms/step
# Epoch 494/500
# 50/50 - 0s - loss: 64.5183 - 113ms/epoch - 2ms/step
# Epoch 495/500
# 50/50 - 0s - loss: 46.9496 - 107ms/epoch - 2ms/step
# Epoch 496/500
# 50/50 - 0s - loss: 47.9881 - 108ms/epoch - 2ms/step
# Epoch 497/500
# 50/50 - 0s - loss: 100.3963 - 120ms/epoch - 2ms/step
# Epoch 498/500
# 50/50 - 0s - loss: 72.4268 - 120ms/epoch - 2ms/step
# Epoch 499/500
# 50/50 - 0s - loss: 65.2442 - 114ms/epoch - 2ms/step
# Epoch 500/500
# 50/50 - 0s - loss: 74.9247 - 107ms/epoch - 2ms/step

# %%
y_pred=model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 110ms/step

# %%
y_pred
# Out:
# array([[366.18704],
#        [340.26556],
#        [387.4145 ],
#        [393.15213],
#        [398.0851 ],
#        [495.09372],
#        [561.09955],
#        [569.3875 ],
#        [471.73706],
#        [417.60916],
#        [363.9283 ],
#        [396.04892],
#        [425.71637],
#        [406.21677],
#        [472.73233],
#        [438.94467],
#        [463.68857],
#        [551.2729 ],
#        [629.5028 ],
#        [639.50415],
#        [529.6161 ],
#        [464.24826],
#        [416.4437 ],
#        [443.54868]], dtype=float32)

# %%
y_test
# Out:
# array([360, 342, 406, 396, 420, 472, 548, 559, 463, 407, 362, 405, 417,
#        391, 419, 461, 472, 535, 622, 606, 508, 461, 390, 432])

# %%
plt.plot(y_test, color='blue',label='Real')
plt.plot(y_pred, color='red',label='Predicted')
plt.title('Real Vs Predicted')
plt.xlabel('Date')
plt.ylabel('Passengers')
# Out:
# Text(0, 0.5, 'Passengers')

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred)).round(2)
mae = np.round(np.mean(np.abs(y_test-y_pred))*100,2)
mape = np.round(np.mean(np.abs(y_test-y_pred)/y_test)*100,2)

# %%
print("RMSE=",rmse)
print("MAE=",mae)
print("MAPE=",mape)
# Out:
# RMSE= 18.78
# MAE= 8644.66
# MAPE= 19.21
